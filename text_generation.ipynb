# %% [markdown]
# In this notebook, we deploy
# - GPT-2,
# - GPT-3.5,
# - OPT,
# - BLOOM
#
# as the generation models and collect the generated sentences.

# %% [markdown]
# ### Load the data

# %%
import pandas as pd
from tqdm import tqdm

# %%
df = pd.read_csv('data/HateXplain/prefix_prompt.csv')

# %% [markdown]
# ### GPT-2

# %% [markdown]
# we use top-1 generation, and the maximum number of generation is 30

# %%
# load the pre-trained model
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')

def gpt2_generate(prefix, max_length=30, num_return_sequences=1):
    set_seed(42)
    sentences = generator(prefix, max_length=max_length, num_return_sequences=num_return_sequences)
    return sentences[0]['generated_text']

# %%
# generate text for each prefix
tqdm.pandas()
df['generated_text'] = df['text'].progress_apply(lambda x: gpt2_generate(x))
# Out:
#   0%|          | 0/2113 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   0%|          | 2/2113 [00:00<02:46, 12.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   0%|          | 4/2113 [00:00<07:35,  4.63it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   0%|          | 6/2113 [00:01<08:18,  4.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   0%|          | 7/2113 [00:01<07:09,  4.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   0%|          | 8/2113 [00:01<08:52,  3.96it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   0%|          | 9/2113 [00:02<09:40,  3.62it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   0%|          | 10/2113 [00:02<09:43,  3.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 12/2113 [00:02<07:59,  4.38it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 13/2113 [00:02<07:16,  4.81it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 14/2113 [00:03<07:06,  4.92it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 15/2113 [00:03<06:35,  5.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 16/2113 [00:03<06:52,  5.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 17/2113 [00:03<08:07,  4.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 18/2113 [00:04<09:20,  3.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 19/2113 [00:04<09:23,  3.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 20/2113 [00:04<09:14,  3.77it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 22/2113 [00:04<07:04,  4.92it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 24/2113 [00:05<06:06,  5.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 25/2113 [00:05<05:33,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 26/2113 [00:05<07:40,  4.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|▏         | 27/2113 [00:06<08:45,  3.97it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|▏         | 28/2113 [00:06<09:44,  3.57it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|▏         | 29/2113 [00:06<09:58,  3.48it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|▏         | 30/2113 [00:07<10:22,  3.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|▏         | 31/2113 [00:07<08:57,  3.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 32/2113 [00:07<09:29,  3.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 33/2113 [00:07<08:27,  4.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 34/2113 [00:07<08:42,  3.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 36/2113 [00:08<06:46,  5.11it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 38/2113 [00:08<07:37,  4.54it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 39/2113 [00:09<08:32,  4.05it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 40/2113 [00:09<07:28,  4.62it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 41/2113 [00:09<09:10,  3.77it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 43/2113 [00:09<07:46,  4.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 44/2113 [00:10<06:48,  5.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 45/2113 [00:10<07:47,  4.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 46/2113 [00:10<07:56,  4.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 47/2113 [00:10<08:55,  3.86it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 48/2113 [00:11<08:59,  3.83it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 49/2113 [00:11<08:04,  4.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 50/2113 [00:11<07:06,  4.84it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 51/2113 [00:11<07:03,  4.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 52/2113 [00:12<08:09,  4.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   3%|▎         | 53/2113 [00:12<08:51,  3.88it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   3%|▎         | 54/2113 [00:12<09:31,  3.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   3%|▎         | 55/2113 [00:12<09:13,  3.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   3%|▎         | 56/2113 [00:13<10:37,  3.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   3%|▎         |
/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|██████████| 2113/2113 [08:48<00:00,  4.00it/s]

# %%
# save the generated text
df.to_csv('data/HateXplain/gpt2_prefix.csv', index=False)

# %%
df
# Out:
#                           post_id  \
# 0     1179088797964763136_twitter
# 1                    13851720_gab
# 2                    19679648_gab
# 3                    23844035_gab
# 4                    14104384_gab
# ...                           ...
# 2108                  9731096_gab
# 2109                  9755956_gab
# 2110                  9798597_gab
# 2111                  9982674_gab
# 2112                  9992513_gab
#
#                                                    text    part  \
# 0     @769288 i am bit confused coz chinese ppl can ...  prefix
# 1     laura loomer raped me while screaming at me in...  prefix
# 2         guilty until proven innocent unless you are a  prefix
# 3     173750 263867 47% of brits think multicultural...  prefix
# 4                             why does anyone care what  prefix
# ...                                                 ...     ...
# 2108  i forgot how much talcum xx lies they turned t...  prefix
# 2109                              do not worry they are  prefix
# 2110  flushed with victory after normalizing trannie...  prefix
# 2111  more and more leftists are moving closer to ce...  prefix
# 2112      it is awful look at world demographics asians  prefix
#
#                                          generated_text
# 0     @769288 i am bit confused coz chinese ppl can ...
# 1     laura loomer raped me while screaming at me in...
# 2     guilty until proven innocent unless you are a ...
# 3     173750 263867 47% of brits think multicultural...
# 4     why does anyone care what I'm doing to create ...
# ...                                                 ...
# 2108  i forgot how much talcum xx lies they turned t...
# 2109        do not worry they are not going anywhere.")
# 2110  flushed with victory after normalizing trannie...
# 2111  more and more leftists are moving closer to ce...
# 2112  it is awful look at world demographics asians,...
#
# [2113 rows x 4 columns]

# %% [markdown]
# ### GPT-j-6B
# https://huggingface.co/EleutherAI/gpt-j-6B

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B")
model = AutoModelForCausalLM.from_pretrained("EleutherAI/gpt-j-6B").to('cuda')
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done

# %%
model

# %% [markdown]
# ### GPT-NeoXT-Chat-Base-20B
# https://huggingface.co/togethercomputer/GPT-NeoXT-Chat-Base-20B?text=My+name+is+Lewis+and+I+like+to

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
tokenizer = AutoTokenizer.from_pretrained("togethercomputer/GPT-NeoXT-Chat-Base-20B")
model = AutoModelForCausalLM.from_pretrained("togethercomputer/GPT-NeoXT-Chat-Base-20B")

# %% [markdown]
# ### OPT-66b
# https://huggingface.co/facebook/opt-66b

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

def opt_generate(prefix, max_length=30, num_return_sequences=1):
    model = AutoModelForCausalLM.from_pretrained("facebook/opt-66b", torch_dtype=torch.float16).cuda()
    tokenizer = AutoTokenizer.from_pretrained("facebook/opt-66b", use_fast=False)
    input_ids = tokenizer(prefix, return_tensors="pt").input_ids.cuda()
    generated_ids = model.generate(input_ids,  num_return_sequences=num_return_sequences, max_length=max_length)
    return tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

# %%
text = "I don't like"
opt_generate(text)
# Out:
# Downloading:   0%|          | 0.00/676 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/89.9k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.80G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.85G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.85G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.51G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.51G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.85G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.85G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.51G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.51G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.85G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.85G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.51G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.51G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/6.36G [00:00<?, ?B/s]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done

# %% [markdown]
# ### BLOOM
# https://huggingface.co/bigscience/bloom

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom")
model = AutoModelForCausalLM.from_pretrained("bigscience/bloom").cuda()
